# %% [markdown]
# # LLM Basics
#
# This notebook introduces the LLM integration layer.

# %%
from backend.llm.llm_factory import LLMFactory

factory = LLMFactory()
llm = factory.get_llm('openai')
response = await llm.generate('You are a helpful assistant', 'Hello!')
print(response)
