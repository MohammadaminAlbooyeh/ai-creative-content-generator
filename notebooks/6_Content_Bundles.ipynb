# %% [markdown]
# # Multi-modal Content Bundles

# %%
from backend.generators.multimodal_generators.social_media_bundle import SocialMediaBundleGenerator

# This requires initialized generators
print('Create multi-platform content with images in one call!')
