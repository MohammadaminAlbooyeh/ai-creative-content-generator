# %% [markdown]
# # Template Creation
#
# Learn how to create and use templates.

# %%
from backend.templates.blog_templates.listicle_template import ListicleTemplate

template = ListicleTemplate()
items = [{'title': 'Top 5 AI Trends', 'intro': 'AI is transforming the world...'}]
result = template.render(items)
print(result)
